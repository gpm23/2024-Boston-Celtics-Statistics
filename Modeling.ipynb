# %% [markdown]
# # Celtics Models

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report

# %% [markdown]
# ## Model A
# #### Categorizing offensive, defensive and dual threat players

# %% [markdown]
# ##### Preprocessing

# %%
# Load the data
data = pd.read_csv('data/averages.csv')
print(data.head())

# Select relevant columns including 'Rk' for reference
data = data[['Rk', 'PTS', 'FT', 'TRB', 'BLK', 'ODtag']]

# Display the first few rows of the data
print(data.head())

# Check for infinite values and replace them with NaN
data.replace([np.inf, -np.inf], np.nan, inplace=True)

# Drop rows with missing values
data.dropna(inplace=True)

# Check for unique values in 'ODtag'
print("Unique values in 'ODtag':", data['ODtag'].unique())

# Ensure target labels are zero-based
data['ODtag'] = data['ODtag'] - 1

# Check again for unique values in 'ODtag'
print("Adjusted unique values in 'ODtag':", data['ODtag'].unique())

# Separate features and target
X = data.drop('ODtag', axis=1)
y = data['ODtag']

# Store the 'Rk' column separately for reference
player_ids = X['Rk']
X = X.drop('Rk', axis=1)

# Normalize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and test sets
X_train, X_test, y_train, y_test, player_ids_train, player_ids_test = train_test_split(X_scaled, y, player_ids, test_size=0.2, random_state=42)

# Convert to TensorFlow datasets
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(len(X_train)).batch(32)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(32)
# Out:
#    Rk              Player  Age   G  GS    MP   FG   FGA    FG%   3P  ...  TRB  \
# 0   1        Jayson Tatum   25  74  74  35.7  9.1  19.3  0.471  3.1  ...  8.1
# 1   2        Jaylen Brown   27  70  70  33.5  9.0  17.9  0.499  2.1  ...  5.5
# 2   3        Jrue Holiday   33  69  69  32.8  4.8  10.0  0.480  2.0  ...  5.4
# 3   4       Derrick White   29  73  73  32.6  5.3  11.5  0.461  2.7  ...  4.2
# 4   5  Kristaps Porziņģis   28  57  57  29.6  6.8  13.2  0.516  1.9  ...  7.2
#
#    AST  STL  BLK  TOV   PF   PTS  First Name  Last Name  ODtag
# 0  4.9  1.0  0.6  2.5  2.0  26.9      Jayson      Tatum      1
# 1  3.6  1.2  0.5  2.4  2.6  23.0      Jaylen      Brown      3
# 2  4.8  0.9  0.8  1.8  1.6  12.5        Jrue    Holiday      3
# 3  5.2  1.0  1.2  1.5  2.1  15.2     Derrick      White      3
# 4  2.0  0.7  1.9  1.6  2.7  20.1    Kristaps  Porziņģis      1
#
# [5 rows x 31 columns]
#    Rk   PTS   FT  TRB  BLK  ODtag
# 0   1  26.9  5.6  8.1  0.6      1
# 1   2  23.0  3.0  5.5  0.5      3
# 2   3  12.5  0.9  5.4  0.8      3
# 3   4  15.2  1.9  4.2  1.2      3
# 4   5  20.1  4.5  7.2  1.9      1
# Unique values in 'ODtag': [1 3 2]
# Adjusted unique values in 'ODtag': [0 2 1]

# %% [markdown]
# ##### Model

# %%
# Build the model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(3, activation='softmax')  # Assuming 3 classes: Offensive (0), Defensive (1), Dual (2)
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(train_dataset, epochs=100, validation_data=test_dataset)

# Evaluate the model
loss, accuracy = model.evaluate(test_dataset)
print(f'Test Accuracy: {accuracy * 100:.2f}%')

# Make predictions
y_pred = model.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)

# Combine player IDs with predictions
predictions = pd.DataFrame({'Rk': player_ids_test, 'True_Label': y_test, 'Predicted_Label': y_pred_labels})

# Display classification report
print(classification_report(y_test, y_pred_labels, target_names=['Offensive', 'Defensive', 'Dual']))

# Print predictions for reference
print(predictions.head(20))  # Displaying first 20 predictions for reference
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 220ms/step - loss: 1.1956 - accuracy: 0.2000 - val_loss: 1.0675 - val_accuracy: 0.2500
# Epoch 2/100
# 1/1 [==============================] - 0s 34ms/step - loss: 1.1778 - accuracy: 0.2000 - val_loss: 1.0656 - val_accuracy: 0.5000
# Epoch 3/100
# 1/1 [==============================] - 0s 36ms/step - loss: 1.1607 - accuracy: 0.2667 - val_loss: 1.0640 - val_accuracy: 0.5000
# Epoch 4/100
# 1/1 [==============================] - 0s 28ms/step - loss: 1.1461 - accuracy: 0.2667 - val_loss: 1.0624 - val_accuracy: 0.5000
# Epoch 5/100
# 1/1 [==============================] - 0s 28ms/step - loss: 1.1338 - accuracy: 0.3333 - val_loss: 1.0604 - val_accuracy: 0.7500
# Epoch 6/100
# 1/1 [==============================] - 0s 29ms/step - loss: 1.1232 - accuracy: 0.2667 - val_loss: 1.0586 - val_accuracy: 0.7500
# Epoch 7/100
# 1/1 [==============================] - 0s 37ms/step - loss: 1.1147 - accuracy: 0.2667 - val_loss: 1.0571 - val_accuracy: 0.7500
# Epoch 8/100
# 1/1 [==============================] - 0s 31ms/step - loss: 1.1062 - accuracy: 0.3333 - val_loss: 1.0560 - val_accuracy: 0.7500
# Epoch 9/100
# 1/1 [==============================] - 0s 26ms/step - loss: 1.0994 - accuracy: 0.3333 - val_loss: 1.0550 - val_accuracy: 0.7500
# Epoch 10/100
# 1/1 [==============================] - 0s 24ms/step - loss: 1.0934 - accuracy: 0.3333 - val_loss: 1.0542 - val_accuracy: 0.7500
# Epoch 11/100
# 1/1 [==============================] - 0s 24ms/step - loss: 1.0880 - accuracy: 0.3333 - val_loss: 1.0533 - val_accuracy: 0.7500
# Epoch 12/100
# 1/1 [==============================] - 0s 23ms/step - loss: 1.0831 - accuracy: 0.3333 - val_loss: 1.0527 - val_accuracy: 0.7500
# Epoch 13/100
# 1/1 [==============================] - 0s 22ms/step - loss: 1.0786 - accuracy: 0.4000 - val_loss: 1.0517 - val_accuracy: 0.5000
# Epoch 14/100
# 1/1 [==============================] - 0s 22ms/step - loss: 1.0741 - accuracy: 0.4667 - val_loss: 1.0499 - val_accuracy: 0.5000
# Epoch 15/100
# 1/1 [==============================] - 0s 25ms/step - loss: 1.0702 - accuracy: 0.4667 - val_loss: 1.0481 - val_accuracy: 0.5000
# Epoch 16/100
# 1/1 [==============================] - 0s 26ms/step - loss: 1.0662 - accuracy: 0.5333 - val_loss: 1.0462 - val_accuracy: 0.5000
# Epoch 17/100
# 1/1 [==============================] - 0s 28ms/step - loss: 1.0624 - accuracy: 0.5333 - val_loss: 1.0441 - val_accuracy: 0.5000
# Epoch 18/100
# 1/1 [==============================] - 0s 26ms/step - loss: 1.0589 - accuracy: 0.4667 - val_loss: 1.0420 - val_accuracy: 0.5000
# Epoch 19/100
# 1/1 [==============================] - 0s 27ms/step - loss: 1.0553 - accuracy: 0.4667 - val_loss: 1.0398 - val_accuracy: 0.5000
# Epoch 20/100
# 1/1 [==============================] - 0s 29ms/step - loss: 1.0517 - accuracy: 0.4667 - val_loss: 1.0377 - val_accuracy: 0.5000
# Epoch 21/100
# 1/1 [==============================] - 0s 23ms/step - loss: 1.0480 - accuracy: 0.5333 - val_loss: 1.0356 - val_accuracy: 0.5000
# Epoch 22/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.0442 - accuracy: 0.5333 - val_loss: 1.0334 - val_accuracy: 0.5000
# Epoch 23/100
# 1/1 [==============================] - 0s 24ms/step - loss: 1.0403 - accuracy: 0.5333 - val_loss: 1.0312 - val_accuracy: 0.5000
# Epoch 24/100
# 1/1 [==============================] - 0s 23ms/step - loss: 1.0362 - accuracy: 0.5333 - val_loss: 1.0288 - val_accuracy: 0.5000
# Epoch 25/100
# 1/1 [==============================] - 0s 24ms/step - loss: 1.0320 - accuracy: 0.4667 - val_loss: 1.0260 - val_accuracy: 0.5000
# Epoch 26/100
# 1/1 [==============================] - 0s 25ms/step - loss: 1.0280 - accuracy: 0.4667 - val_loss: 1.0229 - val_accuracy: 0.5000
# Epoch 27/100
# 1/1 [==============================] - 0s 19ms/step - loss: 1.0242 - accuracy: 0.4667 - val_loss: 1.0199 - val_accuracy: 0.5000
# Epoch 28/100
# 1/1 [==============================] - 0s 23ms/step - loss: 1.0205 - accuracy: 0.4667 - val_loss: 1.0170 - val_accuracy: 0.5000
# Epoch 29/100
# 1/1 [==============================] - 0s 25ms/step - loss: 1.0170 - accuracy: 0.4667 - val_loss: 1.0140 - val_accuracy: 0.5000
# Epoch 30/100
# 1/1 [==============================] - 0s 24ms/step - loss: 1.0135 - accuracy: 0.4667 - val_loss: 1.0109 - val_accuracy: 0.5000
# Epoch 31/100
# 1/1 [==============================] - 0s 26ms/step - loss: 1.0099 - accuracy: 0.4667 - val_loss: 1.0077 - val_accuracy: 0.5000
# Epoch 32/100
# 1/1 [==============================] - 0s 25ms/step - loss: 1.0061 - accuracy: 0.4667 - val_loss: 1.0051 - val_accuracy: 0.5000
# Epoch 33/100
# 1/1 [==============================] - 0s 25ms/step - loss: 1.0023 - accuracy: 0.4667 - val_loss: 1.0025 - val_accuracy: 0.5000
# Epoch 34/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.9983 - accuracy: 0.4667 - val_loss: 0.9996 - val_accuracy: 0.5000
# Epoch 35/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.9941 - accuracy: 0.4667 - val_loss: 0.9966 - val_accuracy: 0.5000
# Epoch 36/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.9899 - accuracy: 0.4667 - val_loss: 0.9937 - val_accuracy: 0.5000
# Epoch 37/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.9855 - accuracy: 0.4667 - val_loss: 0.9907 - val_accuracy: 0.5000
# Epoch 38/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.9810 - accuracy: 0.4667 - val_loss: 0.9877 - val_accuracy: 0.5000
# Epoch 39/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.9763 - accuracy: 0.4667 - val_loss: 0.9845 - val_accuracy: 0.5000
# Epoch 40/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.9716 - accuracy: 0.4667 - val_loss: 0.9813 - val_accuracy: 0.5000
# Epoch 41/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.9667 - accuracy: 0.4667 - val_loss: 0.9780 - val_accuracy: 0.5000
# Epoch 42/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.9618 - accuracy: 0.4667 - val_loss: 0.9746 - val_accuracy: 0.5000
# Epoch 43/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.9567 - accuracy: 0.4667 - val_loss: 0.9716 - val_accuracy: 0.5000
# Epoch 44/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.9516 - accuracy: 0.4667 - val_loss: 0.9682 - val_accuracy: 0.5000
# Epoch 45/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.9464 - accuracy: 0.4667 - val_loss: 0.9645 - val_accuracy: 0.5000
# Epoch 46/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.9411 - accuracy: 0.4667 - val_loss: 0.9611 - val_accuracy: 0.5000
# Epoch 47/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.9357 - accuracy: 0.4667 - val_loss: 0.9575 - val_accuracy: 0.5000
# Epoch 48/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.9303 - accuracy: 0.4667 - val_loss: 0.9540 - val_accuracy: 0.5000
# Epoch 49/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.9247 - accuracy: 0.4667 - val_loss: 0.9506 - val_accuracy: 0.5000
# Epoch 50/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.9190 - accuracy: 0.4667 - val_loss: 0.9466 - val_accuracy: 0.5000
# Epoch 51/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.9131 - accuracy: 0.4667 - val_loss: 0.9426 - val_accuracy: 0.5000
# Epoch 52/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.9071 - accuracy: 0.4667 - val_loss: 0.9387 - val_accuracy: 0.5000
# Epoch 53/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.9010 - accuracy: 0.4667 - val_loss: 0.9341 - val_accuracy: 0.5000
# Epoch 54/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.8948 - accuracy: 0.5333 - val_loss: 0.9297 - val_accuracy: 0.5000
# Epoch 55/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.8883 - accuracy: 0.6000 - val_loss: 0.9253 - val_accuracy: 0.5000
# Epoch 56/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8816 - accuracy: 0.6667 - val_loss: 0.9209 - val_accuracy: 0.5000
# Epoch 57/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.8750 - accuracy: 0.6667 - val_loss: 0.9168 - val_accuracy: 0.5000
# Epoch 58/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.8685 - accuracy: 0.6667 - val_loss: 0.9131 - val_accuracy: 0.5000
# Epoch 59/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.8619 - accuracy: 0.6667 - val_loss: 0.9104 - val_accuracy: 0.5000
# Epoch 60/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.8553 - accuracy: 0.6667 - val_loss: 0.9078 - val_accuracy: 0.5000
# Epoch 61/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.8486 - accuracy: 0.6667 - val_loss: 0.9057 - val_accuracy: 0.5000
# Epoch 62/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.8419 - accuracy: 0.6667 - val_loss: 0.9029 - val_accuracy: 0.5000
# Epoch 63/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.8349 - accuracy: 0.6667 - val_loss: 0.9005 - val_accuracy: 0.5000
# Epoch 64/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.8278 - accuracy: 0.6667 - val_loss: 0.8987 - val_accuracy: 0.5000
# Epoch 65/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.8207 - accuracy: 0.6667 - val_loss: 0.8976 - val_accuracy: 0.5000
# Epoch 66/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.8135 - accuracy: 0.6667 - val_loss: 0.8969 - val_accuracy: 0.5000
# Epoch 67/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.8061 - accuracy: 0.7333 - val_loss: 0.8963 - val_accuracy: 0.5000
# Epoch 68/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.7985 - accuracy: 0.7333 - val_loss: 0.8957 - val_accuracy: 0.5000
# Epoch 69/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.7911 - accuracy: 0.7333 - val_loss: 0.8950 - val_accuracy: 0.5000
# Epoch 70/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.7840 - accuracy: 0.7333 - val_loss: 0.8942 - val_accuracy: 0.5000
# Epoch 71/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.7765 - accuracy: 0.7333 - val_loss: 0.8935 - val_accuracy: 0.5000
# Epoch 72/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.7689 - accuracy: 0.7333 - val_loss: 0.8922 - val_accuracy: 0.5000
# Epoch 73/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.7615 - accuracy: 0.7333 - val_loss: 0.8914 - val_accuracy: 0.5000
# Epoch 74/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.7535 - accuracy: 0.7333 - val_loss: 0.8909 - val_accuracy: 0.5000
# Epoch 75/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.7456 - accuracy: 0.7333 - val_loss: 0.8909 - val_accuracy: 0.7500
# Epoch 76/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.7376 - accuracy: 0.7333 - val_loss: 0.8911 - val_accuracy: 0.7500
# Epoch 77/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.7296 - accuracy: 0.7333 - val_loss: 0.8918 - val_accuracy: 0.7500
# Epoch 78/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.7214 - accuracy: 0.7333 - val_loss: 0.8932 - val_accuracy: 0.7500
# Epoch 79/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.7129 - accuracy: 0.7333 - val_loss: 0.8944 - val_accuracy: 0.7500
# Epoch 80/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.7041 - accuracy: 0.7333 - val_loss: 0.8957 - val_accuracy: 0.7500
# Epoch 81/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6953 - accuracy: 0.7333 - val_loss: 0.8977 - val_accuracy: 0.7500
# Epoch 82/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6861 - accuracy: 0.8000 - val_loss: 0.9002 - val_accuracy: 0.5000
# Epoch 83/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6767 - accuracy: 0.8000 - val_loss: 0.9033 - val_accuracy: 0.5000
# Epoch 84/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.6670 - accuracy: 0.8000 - val_loss: 0.9068 - val_accuracy: 0.5000
# Epoch 85/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6570 - accuracy: 0.8667 - val_loss: 0.9096 - val_accuracy: 0.5000
# Epoch 86/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.6466 - accuracy: 0.8667 - val_loss: 0.9126 - val_accuracy: 0.5000
# Epoch 87/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6362 - accuracy: 0.8667 - val_loss: 0.9159 - val_accuracy: 0.5000
# Epoch 88/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6257 - accuracy: 0.8667 - val_loss: 0.9200 - val_accuracy: 0.5000
# Epoch 89/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.6151 - accuracy: 0.8667 - val_loss: 0.9248 - val_accuracy: 0.5000
# Epoch 90/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.6046 - accuracy: 0.8667 - val_loss: 0.9295 - val_accuracy: 0.5000
# Epoch 91/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.5938 - accuracy: 0.9333 - val_loss: 0.9346 - val_accuracy: 0.5000
# Epoch 92/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.5830 - accuracy: 0.9333 - val_loss: 0.9405 - val_accuracy: 0.5000
# Epoch 93/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.5721 - accuracy: 0.9333 - val_loss: 0.9467 - val_accuracy: 0.5000
# Epoch 94/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.5611 - accuracy: 0.9333 - val_loss: 0.9524 - val_accuracy: 0.5000
# Epoch 95/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.5500 - accuracy: 0.9333 - val_loss: 0.9574 - val_accuracy: 0.5000
# Epoch 96/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.5389 - accuracy: 0.9333 - val_loss: 0.9623 - val_accuracy: 0.5000
# Epoch 97/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.5278 - accuracy: 0.9333 - val_loss: 0.9669 - val_accuracy: 0.5000
# Epoch 98/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.5169 - accuracy: 0.9333 - val_loss: 0.9722 - val_accuracy: 0.5000
# Epoch 99/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.5062 - accuracy: 0.9333 - val_loss: 0.9789 - val_accuracy: 0.5000
# Epoch 100/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.4953 - accuracy: 0.9333 - val_loss: 0.9864 - val_accuracy: 0.5000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.9864 - accuracy: 0.5000
# Test Accuracy: 50.00%
# 1/1 [==============================] - 0s 29ms/step
#               precision    recall  f1-score   support
#
#    Offensive       0.50      0.50      0.50         2
#    Defensive       0.00      0.00      0.00         1
#         Dual       0.50      1.00      0.67         1
#
#     accuracy                           0.50         4
#    macro avg       0.33      0.50      0.39         4
# weighted avg       0.38      0.50      0.42         4
#
#     Rk  True_Label  Predicted_Label
# 0    1           0                2
# 5    6           0                0
# 11  12           1                0
# 1    2           2                2
# C:\Users\Ahanc\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Ahanc\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Ahanc\anaconda3\envs\tf\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
